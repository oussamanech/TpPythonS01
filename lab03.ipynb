# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv("C:/Users/pc/Documents/PY/labPython/cities.csv")
lons = np.array(data['lon'])
print(lons)
# Out:
# [60.6057 50.2212 39.7015 ... 60.5569 65.5393 37.6676]

# %%
#Задание 1

# %%
np.version.version
# Out:
# '1.18.5'

# %%
#Задание 2
# 1.Заполнить массив

# %%
d=[]
l=[]
r=[]
d=np.random.random(random.randrange(1000,5000))
l = np.array(d)
print("L : ", l)
# Out:
# L :  [0.9499204  0.22253892 0.43161962 ... 0.625278   0.39835125 0.52381334]

# %%
#2.Вывести последний элемент массива.
print("индексированное значение : ",l[-1:]) ## возвращает индексированное значение
print("значение : " ,l[-1]) ## возвращает значение
# Out:
# индексированное значение :  [0.52381334]
# значение :  0.5238133385670318

# %%
#3.	Вывести все нечетные числа.
# Out:
# 0.9499203983067591
# 0.222538922305344
# 0.43161961671914695
# 0.6706688886574087
# 0.7008540131478059
# 0.6845223840531394
# 0.8532773337020267
# 0.7972630409876471
# 0.46300398923473773
# 0.9253508099922177
# 0.20942352906437667
# 0.2176036620851871
# 0.3444977213941446
# 0.5341628132769868
# 0.7151583784382958
# 0.5916559480984023
# 0.9958635311564199
# 0.4586362910012667
# 0.7460920290879256
# 0.09718532608546715
# 0.26573207783330477
# 0.08813821534843125
# 0.24980039666826936
# 0.15489946734898785
# 0.16800289903332943
# 0.3199463722825425
# 0.6830145123432503
# 0.7161785329240687
# 0.3647746170180909
# 0.2791272758157426
# 0.16656713287880942
# 0.3197941321234712
# 0.8048712716970798
# 0.7443861844627313
# 0.4966439140921658
# 0.02364265703736035
# 0.6404025413199413
# 0.10525386860551078
# 0.32921301428201943
# 0.7432000984852628
# 0.050044245460470815
# 0.5932989669454538
# 0.8468751751839722
# 0.5239686911094102
# 0.762484902963404
# 0.4828133570395158
# ...

# %%
#4.	Вывести все четные числа.
for i in d:  
    if i % 2 == 0: 
       print(i, end = "\n")

# %%
== null

# %%
#5.	Посчитать сумму всех элементов.
print("сумму всех элементов : ",sum(l))
# Out:
# сумму всех элементов :  644.9885880958379

# %%
#6.	Умножить каждый элемент массива на 5 и прибавить 3.

for i in l:  
    r.append(i*5+3)

# %%
l=r

# %%
#print ("результат : " , l)
l
# Out:
# [7.749601991533796,
#  4.11269461152672,
#  5.158098083595735,
#  6.353344443287043,
#  6.50427006573903,
#  6.422611920265696,
#  7.266386668510133,
#  6.9863152049382355,
#  5.315019946173688,
#  7.626754049961089,
#  4.047117645321883,
#  4.0880183104259356,
#  4.722488606970723,
#  5.670814066384934,
#  6.575791892191479,
#  5.958279740492012,
#  7.9793176557821,
#  5.293181455006334,
#  6.730460145439628,
#  3.4859266304273357,
#  4.328660389166524,
#  3.4406910767421564,
#  4.249001983341347,
#  3.7744973367449393,
#  3.8400144951666473,
#  4.599731861412712,
#  6.415072561716252,
#  6.580892664620343,
#  4.8238730850904545,
#  4.395636379078713,
#  3.832835664394047,
#  4.598970660617356,
#  7.024356358485399,
#  6.721930922313657,
#  5.483219570460829,
#  3.1182132851868016,
#  6.202012706599707,
#  3.526269343027554,
#  4.6460650714100975,
#  6.716000492426314,
#  3.250221227302354,
#  5.9664948347272695,
#  7.234375875919861,
#  5.619843455547051,
#  6.81242451481702,
# ...
